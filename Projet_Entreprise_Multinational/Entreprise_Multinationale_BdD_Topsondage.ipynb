# %% [markdown]
# # Entreprise Multinationale - BdD Topsondage

# %% [markdown]
# ## Partie 1

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine("mysql+pymysql://brahiman:Simplon21!@localhost/Topsondage")
# https://docs.sqlalchemy.org/en/14/core/engines.html
engine
# Out:
# Engine(mysql+pymysql://brahiman:***@localhost/Topsondage)

# %%
pd.read_excel('Data_Professional_Salary_Survey_Responses_1.xlsx')
# Out:
#        Survey Year               Timestamp  SalaryUSD         Country  \
# 0             2021 2020-12-10 08:22:42.696    65000.0          Sweden
# 1             2021 2020-12-10 08:23:22.242   145000.0   United States
# 2             2021 2020-12-10 08:23:37.909   105000.0   United States
# 3             2021 2020-12-10 08:23:48.152    46482.0  United Kingdom
# 4             2021 2020-12-10 08:24:03.600    98800.0   United States
# ...            ...                     ...        ...             ...
# 10336         2017 2017-01-14 15:50:23.936    36549.0  United Kingdom
# 10337         2017 2017-01-15 01:01:21.212    65000.0    Saudi Arabia
# 10338         2017 2017-01-15 03:25:47.422    85000.0     Netherlands
# 10339         2017 2017-01-15 03:37:35.305    90000.0   United States
# 10340         2017 2017-01-15 03:37:59.149    23000.0        Portugal
#
#       PostalCode       PrimaryDatabase  YearsWithThisDatabase  \
# 0            NaN  Microsoft SQL Server                      4
# ...

# %%
pd.read_excel('Data_Professional_Salary_Survey_Responses_1.xlsx')
topsondage_df = pd.read_excel('Data_Professional_Salary_Survey_Responses_1.xlsx')
topsondage_df
# Out:
#        Survey Year               Timestamp  SalaryUSD         Country  \
# 0             2021 2020-12-10 08:22:42.696    65000.0          Sweden
# 1             2021 2020-12-10 08:23:22.242   145000.0   United States
# 2             2021 2020-12-10 08:23:37.909   105000.0   United States
# 3             2021 2020-12-10 08:23:48.152    46482.0  United Kingdom
# 4             2021 2020-12-10 08:24:03.600    98800.0   United States
# ...            ...                     ...        ...             ...
# 10336         2017 2017-01-14 15:50:23.936    36549.0  United Kingdom
# 10337         2017 2017-01-15 01:01:21.212    65000.0    Saudi Arabia
# 10338         2017 2017-01-15 03:25:47.422    85000.0     Netherlands
# 10339         2017 2017-01-15 03:37:35.305    90000.0   United States
# 10340         2017 2017-01-15 03:37:59.149    23000.0        Portugal
#
#       PostalCode       PrimaryDatabase  YearsWithThisDatabase  \
# 0            NaN  Microsoft SQL Server                      4
# ...

# %%
topsondage_df.dtypes
# Out:
# Survey Year                                      int64
# Timestamp                               datetime64[ns]
# SalaryUSD                                      float64
# Country                                         object
# PostalCode                                      object
# PrimaryDatabase                                 object
# YearsWithThisDatabase                            int64
# OtherDatabases                                  object
# EmploymentStatus                                object
# JobTitle                                        object
# ManageStaff                                     object
# YearsWithThisTypeOfJob                           int64
# HowManyCompanies                                object
# OtherPeopleOnYourTeam                           object
# CompanyEmployeesOverall                         object
# DatabaseServers                                 object
# Education                                       object
# ...

# %% [markdown]
# ## Partie 2

# %% [markdown]
# ### 1. Table task

# %%
# 1 / Récupération du nom de chaque colone de la table task
column_task = pd.read_sql_query("select* from task limit 1", engine).columns
column_task
# Out:
# Index(['tas_id', 'tas_name'], dtype='object')

# %%
# 2 / Suppression des doublons de la table task
task = pd.DataFrame(columns = column_task)
task['tas_name'] = topsondage_df['KindsOfTasksPerformed']
task.drop_duplicates(inplace=True)
  
    # NB: A appliquer une fois que les données seront insérées dans la base dD

# %%
# 3 Récupération des clés étrangères

# %%
# 4 Mise à jour de la table

# %%
# 5 Insertion des données de la table dans la base
task = pd.DataFrame(columns = column_task)
task['tas_name'] = topsondage_df['KindsOfTasksPerformed']
task.drop_duplicates(inplace=True)
task.to_sql('task', if_exists='append', con=engine, index=False)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1684                 if not evt_handled:
# -> 1685                     self.dialect.do_executemany(
#    1686                         cursor, statement, parameters, context
#
# ~/anaconda3/lib/python3.8/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# ~/anaconda3/lib/python3.8/site-packages/pymysql/cursors.py in executemany(self, query, args)
# ...

# %% [markdown]
# ### 2. certification

# %%
# 1 / Récupération du nom de chaque colone de la table task
column_certification = pd.read_sql_query("select* from certification limit 1", engine).columns
column_certification

# %%
# 2 / Suppression des doublons de la table task
certification = pd.DataFrame(columns = column_certification)
certification[certification] = topsondage_df[certification]
certification.drop_duplicates(inplace=True)
  
    # NB: A appliquer une fois que les données seront insérées dans la base dD

# %%
# 3 Récupération des clés étrangères

# %%
# 4 Mise à jour de la table

# %%
# 5 Insertion des données de la table dans la base
certification.to_sql('certification', if_exists='append', con=engine, index=False)

# %% [markdown]
# ### 3. country

# %%
# 1 / Récupération du nom de chaque colone de la table task
column_country = pd.read_sql_query("select* from country limit 1", engine).columns
column_country

# %%
# 2 / Suppression des doublons de la table task
country = pd.DataFrame(columns = column_country)
#country[country] = topsondage_df[country]
#country.drop_duplicates(inplace=True)
country  
    # NB: A appliquer une fois que les données seront insérées dans la base dD

# %%
# 3 Récupération des clés étrangères

# %%
# 4 Mise à jour de la table

# %%
# 5 Insertion des données de la table dans la base
country = pd.DataFrame(columns = ["ctr_id", "ctr_name"])
country[ctr_id] = topsondage_df["country"]
country.drop_duplicates(inplace=True)

# %% [markdown]
# ### 4. largest_city

# %%
# 1 / Récupération du nom de chaque colone de la table task
column_largest_city = pd.read_sql_query("select* from largest_city limit 1", engine).columns
column_largest_city
# Out:
# Index(['pop_id', 'pop_name'], dtype='object')

# %%
# 2 / Etablissement correspondance entre nom colone (+ modalités) dataset et nom table (+ ses variables) BdD

# %%
largest_city = pd.DataFrame(columns = column_largest_city)
largest_city['pop_name'] = topsondage_df['PopulationOfLargestCityWithin20Miles']
largest_city
# Out:
#       pop_id              pop_name
# 0        NaN      <= 20,000 (town)
# 1        NaN      1M+ (metropolis)
# 2        NaN  300K-1M (large city)
# 3        NaN  300K-1M (large city)
# 4        NaN      100K-299K (city)
# ...      ...                   ...
# 10336    NaN             Not Asked
# 10337    NaN             Not Asked
# 10338    NaN             Not Asked
# 10339    NaN             Not Asked
# 10340    NaN             Not Asked
#
# [10341 rows x 2 columns]

# %%
# 3 / Suppression des doublons de la table task
largest_city.drop_duplicates(inplace=True)
largest_city

    # NB: A appliquer une fois que les données seront insérées dans la base dD
# Out:
#      pop_id              pop_name
# 0       NaN      <= 20,000 (town)
# 1       NaN      1M+ (metropolis)
# 2       NaN  300K-1M (large city)
# 4       NaN      100K-299K (city)
# 11      NaN  20K-99K (large town)
# 4349    NaN             Not Asked

# %%
# 4 Récupération des clés étrangères

# %%
# 5 Mise à jour de la table

# %%
# 6 Insertion des données de la table dans la base
largest_city.to_sql('largest_city', if_exists='append', con=engine, index=False)

# %% [markdown]
# ### Table task_performed

# %%
# 1 / Récupération du nom de chaque colone de la table task
column_task_performed = pd.read_sql_query("select* from task_performed limit 1", engine).columns
column_task_performed

# %%
# 2 / Suppression des doublons de la table task
task = pd.DataFrame(columns = column_task)
task[task] = topsondage_df[task]
task.drop_duplicates(inplace=True)
  
    # NB: A appliquer une fois que les données seront insérées dans la base dD

# %%
# 3 Récupération des clés étrangères

# %%
# 4 Mise à jour de la table

# %%
# 5 Insertion des données de la table dans la base
